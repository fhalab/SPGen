# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm import tqdm
from scipy.stats import ttest_ind
from numpy import median

input_data_str = 'data/func_class_p0.05_effectsize2.0.csv'
df = pd.read_csv(input_data_str)
df
# Out:
#       Unnamed: 0  correct  protein_id    sp_id  run_label  seqID  \
# 0              0     True  Arnold_002  sps12-2  amylase_1  seq19
# 1              1     True  Arnold_002  sps12-2  amylase_1  seq19
# 2              2     True  Arnold_002  sps12-2  amylase_1  seq19
# 3              3     True  Arnold_002  sps12-2  amylase_1  seq19
# 4              4     True  Arnold_002  sps12-2  amylase_1  seq19
# ...          ...      ...         ...      ...        ...    ...
# 1348        1348     True  Arnold_039     Neg3   negative   seq3
# 1349        1349     True  Arnold_039     Neg3   negative   seq3
# 1350        1350     True  Arnold_039     Neg3   negative   seq3
# 1351        1351     True  Arnold_039     Neg3   negative   seq3
# 1352        1352     True  Arnold_039     Neg3   negative   seq3
#
#       prot_correct  sp_correct    family   run_id  run_index          assay  \
# 0             True        True   amylase  19_12-2         21  assay_3_value
# 1             True        True   amylase  19_12-2         33  assay_1_value
# 2             True        True   amylase  19_12-2         21  assay_4_value
# 3             True        True   amylase  19_12-2         21  assay_1_value
# 4             True        True   amylase  19_12-2         33  assay_2_value
# ...            ...         ...       ...      ...        ...            ...
# 1348          True        True  negative  3_3_neg       1147  assay_1_value
# 1349          True        True  negative  3_3_neg       1144  assay_2_value
# 1350          True        True  negative  3_3_neg       1147  assay_3_value
# 1351          True        True  negative  3_3_neg       1147  assay_2_value
# 1352          True        True  negative  3_3_neg       1144  assay_3_value
#
#       assay_value           old_correct   plot_id   func
# 0           0.502                  True       NaN   True
# 1           0.378                  True  Pro_02-2   True
# 2           0.618                  True       NaN   True
# 3           0.430                  True  Pro_02-2   True
# 4           0.294                  True       NaN   True
# ...           ...                   ...       ...    ...
# 1348        0.572  False (-SP/+Protein)  random_3  False
# 1349        0.384  False (-SP/-Protein)       NaN  False
# 1350        0.484  False (-SP/+Protein)       NaN  False
# 1351        0.574  False (-SP/+Protein)       NaN  False
# 1352        0.472  False (-SP/-Protein)       NaN  False
#
# [1353 rows x 16 columns]

# %%
def sp_prot_match(row):
    ''' Return True if sp matches prot ID and if family is not positive/negative
    '''
    if row['family'] not in ['positive','negative']:
        runID = row['run_id']
        runID = runID.replace('-', '_')
        splits = runID.split('_')
        if splits[0] == splits[1]:
            if splits[-1] not in ['neg','pos']:
                return True
    
    return False

# Get where prot and sp match
df['match'] = df.apply(lambda x: sp_prot_match(x), axis=1)

# %%
cols = list(df.columns)
cols.remove('assay')
cols.remove('assay_value')
cols.remove('Unnamed: 0')
cols.remove('run_index')
cols.remove('old_correct')

df = df.groupby(cols).mean().reset_index()
df = df.drop(['Unnamed: 0', 'assay_value', 'run_index'], axis=1)

### !!!! ####
# Throwing out seq12, which did not have sufficient activity for any construct
df = df[df['seqID'] != 'seq12']

# %%
len(df[df['match']==True])
# Out:
# 29

# %%
# Overall summary
neg = df[df['family']=='negative'].copy()
negfunc = neg[neg['func']==True]
print("{0:.2f}".format(len(negfunc)/len(neg)),':', len(negfunc), 'out of', len(neg), 'negative constructs functional')

pos = df[df['family']=='positive'].copy()
posfunc = pos[pos['func']==True]
print("{0:.2f}".format(len(posfunc)/len(pos)), ':', len(posfunc), 'out of', len(pos), 'positive constructs functional')

gen = df[~df['family'].isin(['positive', 'negative'])].copy()
genfunc = gen[gen['func']==True]
print("{0:.2f}".format(len(genfunc)/len(gen)), ':', len(genfunc), 'out of', len(gen), 'generated functional')

matched = gen[gen['match']==True].copy()
matchfunc = matched[matched['func']==True]
print("{0:.2f}".format(len(matchfunc)/len(matched)), ':', len(matchfunc), 'out of', len(matched), 'sps generated for the matching protein are functional')
# print(lw)
# Out:
# 0.06 : 1 out of 18 negative constructs functional
# 0.79 : 27 out of 34 positive constructs functional
# 0.48 : 53 out of 111 generated functional
# 0.62 : 18 out of 29 sps generated for the matching protein are functional

# %%
gen = df[~df['family'].isin(['positive', 'negative'])].copy()
gen_func = gen[gen['func'] == True]
gen_func.to_csv(input_data_str[:-4] + '_functional.csv')
gen_func
# Out:
#      correct  protein_id    sp_id   run_label  seqID  prot_correct  \
# 12      True  Arnold_001   sps2-2   amylase_2  seq39          True
# 15      True  Arnold_001  sps20-2   amylase_1  seq39          True
# 17      True  Arnold_001  sps20-4   amylase_1  seq39          True
# 19      True  Arnold_001  sps39-3   amylase_1  seq39          True
# 20      True  Arnold_001  sps39-4   amylase_1  seq39          True
# 22      True  Arnold_002  sps12-2   amylase_1  seq19          True
# 23      True  Arnold_002  sps12-4   amylase_1  seq19          True
# 24      True  Arnold_002  sps19-1   amylase_1  seq19          True
# 25      True  Arnold_002  sps19-2   amylase_1  seq19          True
# 26      True  Arnold_002  sps19-3   amylase_1  seq19          True
# 27      True  Arnold_002  sps19-4   amylase_1  seq19          True
# 28      True  Arnold_002   sps3-1   amylase_1  seq19          True
# 40      True  Arnold_003  sps13-3   amylase_1  seq33          True
# 41      True  Arnold_003  sps13-4   amylase_1  seq33          True
# 42      True  Arnold_003  sps18-2   amylase_2  seq33          True
# 47      True  Arnold_003  sps33-4   amylase_1  seq33          True
# 51      True  Arnold_004  sps12-1   amylase_1   seq5          True
# 52      True  Arnold_004  sps13-3   amylase_1   seq5          True
# 55      True  Arnold_004  sps15-3   amylase_2   seq5          True
# 59      True  Arnold_004  sps18-3   amylase_2   seq5          True
# 60      True  Arnold_004  sps18-4   amylase_2   seq5          True
# 63      True  Arnold_004   sps5-3   amylase_2   seq5          True
# 64      True  Arnold_004   sps5-4   amylase_2   seq5          True
# 66      True  Arnold_015  sps19-4   amylase_2  seq21          True
# 67      True  Arnold_015  sps21-1   amylase_2  seq21          True
# 68      True  Arnold_015  sps21-2   amylase_2  seq21          True
# 70      True  Arnold_015  sps21-4   amylase_2  seq21          True
# 73      True  Arnold_015  sps24-4   amylase_2  seq21          True
# 74      True  Arnold_015  sps36-3   amylase_2  seq21          True
# 75      True  Arnold_015  sps36-4   amylase_2  seq21          True
# 85      True  Arnold_026  sps18-2    lipase_1  seq25          True
# 89      True  Arnold_026  sps21-2    lipase_1  seq25          True
# 90      True  Arnold_026  sps21-3    lipase_1  seq25          True
# 91      True  Arnold_026  sps21-4    lipase_1  seq25          True
# 93      True  Arnold_026  sps25-2    lipase_1  seq25          True
# 94      True  Arnold_026  sps25-3    lipase_1  seq25          True
# 95      True  Arnold_026  sps25-4    lipase_1  seq25          True
# 100     True  Arnold_034  sps13-3  protease_1  seq36          True
# 105     True  Arnold_034   sps9-2  protease_1  seq36          True
# 117     True  Arnold_036  sps10-2  protease_2   seq1          True
# 120     True  Arnold_036  sps21-4  protease_2   seq1          True
# 121     True  Arnold_036  sps22-2  protease_1   seq1          True
# 122     True  Arnold_036  sps22-3  protease_1   seq1          True
# 136     True  Arnold_039  sps12-4  xylanase_1   seq3          True
# 142     True  Arnold_039  sps39-4  xylanase_1   seq3          True
# 153     True  Arnold_040  sps24-3  xylanase_1  seq26          True
# 154     True  Arnold_040  sps24-4  xylanase_1  seq26          True
# 155     True  Arnold_040  sps26-1  xylanase_1  seq26          True
# 156     True  Arnold_040  sps26-2  xylanase_1  seq26          True
# 157     True  Arnold_040  sps26-3  xylanase_1  seq26          True
# 159     True  Arnold_040  sps40-1  xylanase_1  seq26          True
# 160     True  Arnold_040  sps40-2  xylanase_1  seq26          True
# 161     True  Arnold_040  sps40-3  xylanase_1  seq26          True
#
#      sp_correct    family   run_id   plot_id  func  match
# 12         True   amylase   39_2-2  Lip_08-2  True  False
# 15         True   amylase  39_20-2  Pro_04-2  True  False
# 17         True   amylase  39_20-4  Pro_04-4  True  False
# 19         True   amylase  39_39-3  Amy_01-3  True   True
# 20         True   amylase  39_39-4  Amy_01-4  True   True
# 22         True   amylase  19_12-2  Pro_02-2  True  False
# 23         True   amylase  19_12-4  Pro_02-4  True  False
# 24         True   amylase  19_19-1  Amy_02-1  True   True
# 25         True   amylase  19_19-2  Amy_02-2  True   True
# 26         True   amylase  19_19-3  Amy_02-3  True   True
# 27         True   amylase  19_19-4  Amy_02-4  True   True
# 28         True   amylase   19_3-1  Xyl_03-1  True  False
# 40         True   amylase  33_13-3  Lip_06-3  True  False
# 41         True   amylase  33_13-4  Lip_06-4  True  False
# 42         True   amylase  33_18-2  Pro_01-2  True  False
# 47         True   amylase  33_33-4  Amy_03-4  True   True
# 51         True   amylase   5_12-1  Pro_02-1  True  False
# 52         True   amylase   5_13-3  Lip_06-3  True  False
# 55         True   amylase   5_15-3  Lip_09-3  True  False
# 59         True   amylase   5_18-3  Pro_01-3  True  False
# 60         True   amylase   5_18-4  Pro_01-4  True  False
# 63         True   amylase    5_5-3  Amy_04-3  True   True
# 64         True   amylase    5_5-4  Amy_04-4  True   True
# 66         True   amylase  21_19-4  Amy_02-4  True  False
# 67         True   amylase  21_21-1  Amy_15-1  True   True
# 68         True   amylase  21_21-2  Amy_15-2  True   True
# 70         True   amylase  21_21-4  Amy_15-4  True   True
# 73         True   amylase  21_24-4  Lip_03-4  True  False
# 74         True   amylase  21_36-3  Pro_03-3  True  False
# 75         True   amylase  21_36-4  Pro_03-4  True  False
# 85         True    lipase  25_18-2  Pro_01-2  True  False
# 89         True    lipase  25_21-2  Amy_15-2  True  False
# 90         True    lipase  25_21-3  Amy_15-3  True  False
# 91         True    lipase  25_21-4  Amy_15-4  True  False
# 93         True    lipase  25_25-2  Lip_05-2  True   True
# 94         True    lipase  25_25-3  Lip_05-3  True   True
# 95         True    lipase  25_25-4  Lip_05-4  True   True
# 100        True  protease  36_13-3  Lip_06-3  True  False
# 105        True  protease   36_9-2  Xyl_01-2  True  False
# 117        True  protease   1_10-2  Xyl_02-2  True  False
# 120        True  protease   1_21-4  Amy_15-4  True  False
# 121        True  protease   1_22-2  Lip_07-2  True  False
# 122        True  protease   1_22-3  Lip_07-3  True  False
# 136        True  xylanase   3_12-4  Pro_02-4  True  False
# 142        True  xylanase   3_39-4  Amy_01-4  True  False
# 153        True  xylanase  26_24-3  Lip_03-3  True  False
# 154        True  xylanase  26_24-4  Lip_03-4  True  False
# 155        True  xylanase  26_26-1  Xyl_04-1  True   True
# 156        True  xylanase  26_26-2  Xyl_04-2  True   True
# 157        True  xylanase  26_26-3  Xyl_04-3  True   True
# 159        True  xylanase  26_40-1  Amy_06-1  True  False
# 160        True  xylanase  26_40-2  Amy_06-2  True  False
# 161        True  xylanase  26_40-3  Amy_06-3  True  False

# %%
# For each protein target
seqs = list(set(df['seqID'].values))
seqs.sort()

neg_total=0
negfunc_total = 0

for seqID in seqs:
    print(seqID)
    # Get the fraction of functioning negatives, generated, and natural SPs (numbers)
    _df = df[df['seqID'] == seqID].copy()
    print(_df.iloc[0]['protein_id'])
    
    # Controls
    neg = _df[_df['family']=='negative'].copy()
    negfunc = neg[neg['func']==True]
    pos = _df[_df['family']=='positive'].copy()
    posfunc = pos[pos['func']==True]
    
    if len(neg) != 0:
        print("{0:.2f}".format(len(negfunc)/len(neg)), ':', len(negfunc), 'out of', len(neg), 'negatives functional')
    else:
        print('no negatives found')    
        
    if len(pos) != 0:
        print("{0:.2f}".format(len(posfunc)/len(pos)), ':', len(posfunc), 'out of', len(pos), 'positives functional')
    else:
        print('no positives found')
        
    # Generated data
    gen = _df[~_df['family'].isin(['negative','positive'])].copy()
    genfunc = gen[gen['func']==True]
    if len(gen) != 0:
        print("{0:.2f}".format(len(genfunc)/len(gen)), ':', len(genfunc), 'out of', len(gen), 'generated functional')
    else:
        print('no generated functional')
        
    matched = gen[gen['match']==True].copy()
    matchfunc = matched[matched['func']==True]
    if len(matched) != 0:
        print("{0:.2f}".format(len(matchfunc)/len(matched)), ':', len(matchfunc), 'out of', len(matched), 'generated for', str(seqID), 'functional')
    else:
        print('no matched found')
    print('-----\n')

# Also get the number where SP matches prot
# Out:
# seq1
# Arnold_036
# 0.33 : 1 out of 3 negatives functional
# 0.83 : 5 out of 6 positives functional
# 0.50 : 4 out of 8 generated functional
# no matched found
# -----
#
# seq19
# Arnold_002
# no negatives found
# no positives found
# 0.70 : 7 out of 10 generated functional
# 1.00 : 4 out of 4 generated for seq19 functional
# -----
#
# seq21
# Arnold_015
# no negatives found
# 1.00 : 1 out of 1 positives functional
# 0.70 : 7 out of 10 generated functional
# 0.75 : 3 out of 4 generated for seq21 functional
# -----
#
# seq25
# Arnold_026
# 0.00 : 0 out of 3 negatives functional
# 0.80 : 4 out of 5 positives functional
# 0.58 : 7 out of 12 generated functional
# 0.75 : 3 out of 4 generated for seq25 functional
# -----
#
# seq26
# Arnold_040
# 0.00 : 0 out of 3 negatives functional
# 0.80 : 4 out of 5 positives functional
# 0.67 : 8 out of 12 generated functional
# 0.75 : 3 out of 4 generated for seq26 functional
# -----
#
# seq3
# Arnold_039
# 0.00 : 0 out of 3 negatives functional
# 0.50 : 3 out of 6 positives functional
# 0.20 : 2 out of 10 generated functional
# 0.00 : 0 out of 3 generated for seq3 functional
# -----
#
# seq33
# Arnold_003
# 0.00 : 0 out of 3 negatives functional
# 1.00 : 5 out of 5 positives functional
# 0.33 : 4 out of 12 generated functional
# 0.25 : 1 out of 4 generated for seq33 functional
# -----
#
# seq36
# Arnold_034
# no negatives found
# no positives found
# 0.18 : 2 out of 11 generated functional
# no matched found
# -----
#
# seq39
# Arnold_001
# 0.00 : 0 out of 3 negatives functional
# 0.83 : 5 out of 6 positives functional
# 0.42 : 5 out of 12 generated functional
# 0.67 : 2 out of 3 generated for seq39 functional
# -----
#
# seq5
# Arnold_004
# no negatives found
# no positives found
# 0.50 : 7 out of 14 generated functional
# 0.67 : 2 out of 3 generated for seq5 functional
# -----
